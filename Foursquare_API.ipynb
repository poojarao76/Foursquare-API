# %% [markdown]
# ## Learning FourSquare API with Python
#
# ### Introduction:
#
# In this lab, you will learn in details how to make calls to the Foursquare API for different purposes. You will learn how to construct a URL to send a request to the API to search for a specific type of venues, to explore a particular venue.

# %%
pip install python-dotenv
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install geopy
# Out:
# Requirement already satisfied: geopy in c:\users\raopo\anaconda3\lib\site-packages (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\raopo\anaconda3\lib\site-packages (from geopy) (2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv
from geopy.geocoders import Nominatim   # module to convert an address into latitude and longitude values
import requests
from pandas import json_normalize   # tranforming json file into a pandas dataframe

# %%
# Define the content of the .env file
env_content = """
DB_ID=UWRB20B2EYP153CFGL0K3SJLNL0LGBIY5RSYFO3X2CNAPUC4
DB_SECRET=E4MC1PE4CLKJZZ0ZC3E1MZ2ZV4R2X2BWZ334UYPARUAJADH2
"""

# Specify the path to the .env file
env_file_path = '.env'

# Write the content to the .env file
with open(env_file_path, 'w') as env_file:
    env_file.write(env_content)

# Print a message indicating that the file has been created
print(f".env file created at {os.path.abspath(env_file_path)}")
# Out:
# .env file created at C:\Users\raopo\Desktop\Projects\Data_Science\.env

# %%
# Load variables from .env file
load_dotenv()
# Out:
# True

# %%
# Access environment variables
db_username = os.environ.get('DB_ID')
db_password = os.environ.get('DB_SECRET')

print("DB_ID:", db_username)
print("DB_SECRET:", db_password)
# Out:
# DB_ID: UWRB20B2EYP153CFGL0K3SJLNL0LGBIY5RSYFO3X2CNAPUC4
# DB_SECRET: E4MC1PE4CLKJZZ0ZC3E1MZ2ZV4R2X2BWZ334UYPARUAJADH2

# %% [markdown]
# #### Define Foursquare Credentials and Version

# %%
CLIENT_ID = os.environ.get('DB_ID') # your Foursquare ID
CLIENT_SECRET = os.environ.get('DB_SECRET') # your Foursquare Secret
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: UWRB20B2EYP153CFGL0K3SJLNL0LGBIY5RSYFO3X2CNAPUC4
# CLIENT_SECRET:E4MC1PE4CLKJZZ0ZC3E1MZ2ZV4R2X2BWZ334UYPARUAJADH2

# %%
address = '102 North End Ave, New York, NY'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 40.7149555 -74.0153365

# %% [markdown]
# ## 1. Search for a specific venue category

# %% [markdown]
# Now, let's assume that it is lunch time, and you are craving Italian food. So, let's define a query to search for Italian food that is within 500 metres from the Conrad Hotel.

# %%
search_query = 'italian'
radius = 500
ll = f'{latitude},{longitude}'

# %% [markdown]
# #### Define the URL

# %%
base_url = "https://api.foursquare.com/v3/places/search"
url = f"{base_url}?query={search_query}&radius={radius}&ll={ll}"

headers = {
    "accept": "application/json",
    "Authorization": "fsq3slWZEeFW743yx8er5OvDF1NCO2Z5R8qnD2QTiYii1sA="
}

result = requests.get(url, headers=headers)

data = result.json()
data
# Out:
# {'results': [{'fsq_id': '5d41d093104e90000882db55',
#    'categories': [{'id': 13003,
#      'name': 'Bar',
#      'short_name': 'Bar',
#      'plural_name': 'Bars',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'}},
#     {'id': 13236,
#      'name': 'Italian Restaurant',
#      'short_name': 'Italian',
#      'plural_name': 'Italian Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'Unsure',
#    'distance': 171,
#    'geocodes': {'main': {'latitude': 40.713759, 'longitude': -74.014339},
#     'roof': {'latitude': 40.713759, 'longitude': -74.014339}},
#    'link': '/v3/places/5d41d093104e90000882db55',
#    'location': {'address': '200 Vesey St',
#     'census_block': '360610317031002',
#     'country': 'US',
#     'cross_street': 'West St',
#     'dma': 'New York',
#     'formatted_address': '200 Vesey St (West St), New York, NY 10281',
#     'locality': 'New York',
#     'postcode': '10281',
#     'region': 'NY'},
#    'name': 'Sant Ambroeus Brookfield',
#    'related_places': {},
#    'timezone': 'America/New_York'},
#   {'fsq_id': '60eda733a7ddae4973db6ee8',
#    'categories': [{'id': 13236,
#      'name': 'Italian Restaurant',
#      'short_name': 'Italian',
#      'plural_name': 'Italian Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#       'suffix': '.png'}},
#     {'id': 13334,
#      'name': 'Sandwich Spot',
#      'short_name': 'Sandwich Spot',
#      'plural_name': 'Sandwich Spots',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 181,
#    'geocodes': {'main': {'latitude': 40.713984, 'longitude': -74.015963},
#     'roof': {'latitude': 40.713984, 'longitude': -74.015963}},
#    'link': '/v3/places/60eda733a7ddae4973db6ee8',
#    'location': {'address': '250 Vesey St',
#     'census_block': '360610317031002',
#     'country': 'US',
#     'cross_street': 'Suite 107B',
#     'dma': 'New York',
#     'formatted_address': '250 Vesey St (Suite 107B), New York, NY 10281',
#     'locality': 'New York',
#     'postcode': '10281',
#     'region': 'NY'},
#    'name': 'Cicci Di Carne',
#    'related_places': {},
#    'timezone': 'America/New_York'},
#   {'fsq_id': '63d58772256bdb3de18e26dd',
#    'categories': [{'id': 13236,
#      'name': 'Italian Restaurant',
#      'short_name': 'Italian',
#      'plural_name': 'Italian Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 188,
#    'geocodes': {'drop_off': {'latitude': 40.713967, 'longitude': -74.014647},
#     'main': {'latitude': 40.713857, 'longitude': -74.014692},
#     'roof': {'latitude': 40.713857, 'longitude': -74.014692}},
#    'link': '/v3/places/63d58772256bdb3de18e26dd',
#    'location': {'address': '200 Vesey St',
#     'census_block': '360610317031002',
#     'country': 'US',
#     'cross_street': '',
#     'dma': 'New York',
#     'formatted_address': '200 Vesey St, New York, NY 10281',
#     'locality': 'New York',
#     'postcode': '10281',
#     'region': 'NY'},
#    'name': 'St Ambroeus',
#    'related_places': {},
#    'timezone': 'America/New_York'},
#   {'fsq_id': '3fd66200f964a520aae61ee3',
#    'categories': [{'id': 13064,
#      'name': 'Pizzeria',
#      'short_name': 'Pizza',
#      'plural_name': 'Pizzerias',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#       'suffix': '.png'}},
#     {'id': 13236,
#      'name': 'Italian Restaurant',
#      'short_name': 'Italian',
#      'plural_name': 'Italian Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 470,
#    'geocodes': {'drop_off': {'latitude': 40.717301, 'longitude': -74.010671},
#     'main': {'latitude': 40.717261, 'longitude': -74.010506},
#     'roof': {'latitude': 40.717261, 'longitude': -74.010506}},
#    'link': '/v3/places/3fd66200f964a520aae61ee3',
#    'location': {'address': '323 Greenwich St',
#     'address_extended': 'Frnt 1',
#     'census_block': '360610039003010',
#     'country': 'US',
#     'cross_street': 'btw Duane & Reade Sts.',
#     'dma': 'New York',
#     'formatted_address': '323 Greenwich St (btw Duane & Reade Sts.), New York, NY 10013',
#     'locality': 'New York',
#     'postcode': '10013',
#     'region': 'NY'},
#    'name': 'Gigino Trattoria',
#    'related_places': {},
#    'timezone': 'America/New_York'},
#   {'fsq_id': '592b5e9c0ff4f9137e2a8390',
#    'categories': [{'id': 13025,
#      'name': 'Wine Bar',
#      'short_name': 'Wine Bar',
#      'plural_name': 'Wine Bars',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#       'suffix': '.png'}},
#     {'id': 13236,
#      'name': 'Italian Restaurant',
#      'short_name': 'Italian',
#      'plural_name': 'Italian Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 490,
#    'geocodes': {'drop_off': {'latitude': 40.717433, 'longitude': -74.010365},
#     'main': {'latitude': 40.717319, 'longitude': -74.010378},
#     'roof': {'latitude': 40.717319, 'longitude': -74.010378}},
#    'link': '/v3/places/592b5e9c0ff4f9137e2a8390',
#    'location': {'address': '190A Duane St',
#     'census_block': '360610039003010',
#     'country': 'US',
#     'cross_street': 'Greenwich',
#     'dma': 'New York',
#     'formatted_address': '190A Duane St (Greenwich), New York, NY 10013',
#     'locality': 'New York',
#     'postcode': '10013',
#     'region': 'NY'},
#    'name': "L' Angolo Tribeca",
#    'related_places': {},
#    'timezone': 'America/New_York'},
#   {'fsq_id': 'd462e1585b104ed413c3292d',
#    'categories': [{'id': 13236,
#      'name': 'Italian Restaurant',
#      'short_name': 'Italian',
#      'plural_name': 'Italian Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 478,
#    'geocodes': {'main': {'latitude': 40.715932, 'longitude': -74.009799},
#     'roof': {'latitude': 40.715932, 'longitude': -74.009799}},
#    'link': '/v3/places/d462e1585b104ed413c3292d',
#    'location': {'address': '147 Chambers St',
#     'census_block': '360610021003000',
#     'country': 'US',
#     'dma': 'New York',
#     'formatted_address': '147 Chambers St, New York, NY 10007',
#     'locality': 'New York',
#     'postcode': '10007',
#     'region': 'NY'},
#    'name': 'iPizzaNY',
#    'related_places': {}},
#   {'fsq_id': '95e98b4cb7e64cfc140c5d29',
#    'categories': [{'id': 13099,
#      'name': 'Chinese Restaurant',
#      'short_name': 'Chinese',
#      'plural_name': 'Chinese Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#       'suffix': '.png'}},
#     {'id': 13236,
#      'name': 'Italian Restaurant',
#      'short_name': 'Italian',
#      'plural_name': 'Italian Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#       'suffix': '.png'}},
#     {'id': 13347,
#      'name': 'Tapas Restaurant',
#      'short_name': 'Tapas',
#      'plural_name': 'Tapas Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 53,
#    'geocodes': {'main': {'latitude': 40.715203, 'longitude': -74.014789},
#     'roof': {'latitude': 40.715203, 'longitude': -74.014789}},
#    'link': '/v3/places/95e98b4cb7e64cfc140c5d29',
#    'location': {'address': '222 Murray St',
#     'census_block': '360610317033007',
#     'country': 'US',
#     'dma': 'New York',
#     'formatted_address': '222 Murray St, New York, NY 10282',
#     'locality': 'New York',
#     'postcode': '10282',
#     'region': 'NY'},
#    'name': 'Global Cuisine',
#    'related_places': {},
#    'timezone': 'America/New_York'},
#   {'fsq_id': '621bd89fdda85a16a2075f0c',
#    'categories': [{'id': 13064,
#      'name': 'Pizzeria',
#      'short_name': 'Pizza',
#      'plural_name': 'Pizzerias',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 288,
#    'geocodes': {'drop_off': {'latitude': 40.7115, 'longitude': -74.015291},
#     'main': {'latitude': 40.711686, 'longitude': -74.015217},
#     'roof': {'latitude': 40.711686, 'longitude': -74.015217}},
#    'link': '/v3/places/621bd89fdda85a16a2075f0c',
#    'location': {'address': '225 Liberty St',
#     'census_block': '360610317031002',
#     'country': 'US',
#     'cross_street': '',
#     'dma': 'New York',
#     'formatted_address': '225 Liberty St, New York, NY 10281',
#     'locality': 'New York',
#     'postcode': '10281',
#     'region': 'NY'},
#    'name': 'Sauce pizzeria',
#    'related_places': {},
#    'timezone': 'America/New_York'},
#   {'fsq_id': '3a083b30a7744cb94f3fe6da',
#    'categories': [{'id': 13064,
#      'name': 'Pizzeria',
#      'short_name': 'Pizza',
#      'plural_name': 'Pizzerias',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#       'suffix': '.png'}},
#     {'id': 13236,
#      'name': 'Italian Restaurant',
#      'short_name': 'Italian',
#      'plural_name': 'Italian Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 483,
#    'geocodes': {'main': {'latitude': 40.715987, 'longitude': -74.009757},
#     'roof': {'latitude': 40.715987, 'longitude': -74.009757}},
#    'link': '/v3/places/3a083b30a7744cb94f3fe6da',
#    'location': {'address': '147 Chambers St',
#     'census_block': '360610021003000',
#     'country': 'US',
#     'dma': 'New York',
#     'formatted_address': '147 Chambers St, New York, NY 10007',
#     'locality': 'New York',
#     'postcode': '10007',
#     'region': 'NY'},
#    'name': "Cafe Amore's Restaurant",
#    'related_places': {}}],
#  'context': {'geo_bounds': {'circle': {'center': {'latitude': 40.7149555,
#      'longitude': -74.0153365},
#     'radius': 500}}}}

# %% [markdown]
# #### Get relevant part of JSON and transform it into a pandas dataframe

# %%
# assign relevant part of JSON to venues
venues = data['results']

# tranform venues into a dataframe
df = json_normalize(venues)
df.head()
# Out:
#                      fsq_id  \
# 0  5d41d093104e90000882db55
# 1  60eda733a7ddae4973db6ee8
# 2  63d58772256bdb3de18e26dd
# 3  3fd66200f964a520aae61ee3
# 4  592b5e9c0ff4f9137e2a8390
#
#                                           categories chains   closed_bucket  \
# 0  [{'id': 13003, 'name': 'Bar', 'short_name': 'B...     []          Unsure
# 1  [{'id': 13236, 'name': 'Italian Restaurant', '...     []  VeryLikelyOpen
# 2  [{'id': 13236, 'name': 'Italian Restaurant', '...     []      LikelyOpen
# 3  [{'id': 13064, 'name': 'Pizzeria', 'short_name...     []      LikelyOpen
# 4  [{'id': 13025, 'name': 'Wine Bar', 'short_name...     []      LikelyOpen
#
#    distance                                 link                      name  \
# 0       171  /v3/places/5d41d093104e90000882db55  Sant Ambroeus Brookfield
# 1       181  /v3/places/60eda733a7ddae4973db6ee8            Cicci Di Carne
# 2       188  /v3/places/63d58772256bdb3de18e26dd               St Ambroeus
# 3       470  /v3/places/3fd66200f964a520aae61ee3          Gigino Trattoria
# 4       490  /v3/places/592b5e9c0ff4f9137e2a8390         L' Angolo Tribeca
#
#            timezone  geocodes.main.latitude  geocodes.main.longitude  ...  \
# 0  America/New_York               40.713759               -74.014339  ...
# 1  America/New_York               40.713984               -74.015963  ...
# 2  America/New_York               40.713857               -74.014692  ...
# 3  America/New_York               40.717261               -74.010506  ...
# 4  America/New_York               40.717319               -74.010378  ...
#
#    location.country   location.cross_street location.dma  \
# 0                US                 West St     New York
# 1                US              Suite 107B     New York
# 2                US                             New York
# 3                US  btw Duane & Reade Sts.     New York
# 4                US               Greenwich     New York
#
#                           location.formatted_address location.locality  \
# 0         200 Vesey St (West St), New York, NY 10281          New York
# 1      250 Vesey St (Suite 107B), New York, NY 10281          New York
# 2                   200 Vesey St, New York, NY 10281          New York
# 3  323 Greenwich St (btw Duane & Reade Sts.), New...          New York
# 4      190A Duane St (Greenwich), New York, NY 10013          New York
#
#   location.postcode location.region geocodes.drop_off.latitude  \
# 0             10281              NY                        NaN
# 1             10281              NY                        NaN
# 2             10281              NY                  40.713967
# 3             10013              NY                  40.717301
# 4             10013              NY                  40.717433
#
#   geocodes.drop_off.longitude location.address_extended
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                  -74.014647                       NaN
# 3                  -74.010671                    Frnt 1
# 4                  -74.010365                       NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# #### Define information of interest and filter dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['fsq_id' ,'name'] + [col for col in df.columns if col.startswith('location.')]
df_filtered = df.loc[:, filtered_columns]
# df_filtered

def get_category_type(row):
    categories_list = row['categories']
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# Apply the get_category_type function to each row to extract the category
df_filtered['categories'] = df.apply(get_category_type, axis=1)

# Clean column names by keeping only the last term
df_filtered.columns = [column.split('.')[-1] for column in df_filtered.columns]

# Display the filtered DataFrame
df_filtered
# Out:
#                      fsq_id                      name           address  \
# 0  5d41d093104e90000882db55  Sant Ambroeus Brookfield      200 Vesey St
# 1  60eda733a7ddae4973db6ee8            Cicci Di Carne      250 Vesey St
# 2  63d58772256bdb3de18e26dd               St Ambroeus      200 Vesey St
# 3  3fd66200f964a520aae61ee3          Gigino Trattoria  323 Greenwich St
# 4  592b5e9c0ff4f9137e2a8390         L' Angolo Tribeca     190A Duane St
# 5  d462e1585b104ed413c3292d                  iPizzaNY   147 Chambers St
# 6  95e98b4cb7e64cfc140c5d29            Global Cuisine     222 Murray St
# 7  621bd89fdda85a16a2075f0c            Sauce pizzeria    225 Liberty St
# 8  3a083b30a7744cb94f3fe6da   Cafe Amore's Restaurant   147 Chambers St
#
#       census_block country            cross_street       dma  \
# 0  360610317031002      US                 West St  New York
# 1  360610317031002      US              Suite 107B  New York
# 2  360610317031002      US                          New York
# 3  360610039003010      US  btw Duane & Reade Sts.  New York
# 4  360610039003010      US               Greenwich  New York
# 5  360610021003000      US                     NaN  New York
# 6  360610317033007      US                     NaN  New York
# 7  360610317031002      US                          New York
# 8  360610021003000      US                     NaN  New York
#
#                                    formatted_address  locality postcode  \
# 0         200 Vesey St (West St), New York, NY 10281  New York    10281
# 1      250 Vesey St (Suite 107B), New York, NY 10281  New York    10281
# 2                   200 Vesey St, New York, NY 10281  New York    10281
# 3  323 Greenwich St (btw Duane & Reade Sts.), New...  New York    10013
# 4      190A Duane St (Greenwich), New York, NY 10013  New York    10013
# 5                147 Chambers St, New York, NY 10007  New York    10007
# 6                  222 Murray St, New York, NY 10282  New York    10282
# 7                 225 Liberty St, New York, NY 10281  New York    10281
# 8                147 Chambers St, New York, NY 10007  New York    10007
#
#   region address_extended          categories
# 0     NY              NaN                 Bar
# 1     NY              NaN  Italian Restaurant
# 2     NY              NaN  Italian Restaurant
# 3     NY           Frnt 1            Pizzeria
# 4     NY              NaN            Wine Bar
# 5     NY              NaN  Italian Restaurant
# 6     NY              NaN  Chinese Restaurant
# 7     NY              NaN            Pizzeria
# 8     NY              NaN            Pizzeria

# %% [markdown]
# ## 2. Explore a Given Venue
#
# ### A. Let's explore the closest Italian restaurant -- Cafe Amore's Restaurant

# %%
venue_id = '60eda733a7ddae4973db6ee8'

base_url = "https://api.foursquare.com/v3/places/"
url = url = f"{base_url}{venue_id}"

headers = {
    "accept": "application/json",
    "Authorization": "fsq3slWZEeFW743yx8er5OvDF1NCO2Z5R8qnD2QTiYii1sA="
}

response = requests.get(url, headers=headers)
data = response.json()
data
# Out:
# {'fsq_id': '60eda733a7ddae4973db6ee8',
#  'categories': [{'id': 13236,
#    'name': 'Italian Restaurant',
#    'short_name': 'Italian',
#    'plural_name': 'Italian Restaurants',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#     'suffix': '.png'}},
#   {'id': 13334,
#    'name': 'Sandwich Spot',
#    'short_name': 'Sandwich Spot',
#    'plural_name': 'Sandwich Spots',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#     'suffix': '.png'}}],
#  'chains': [],
#  'closed_bucket': 'VeryLikelyOpen',
#  'geocodes': {'main': {'latitude': 40.713984, 'longitude': -74.015963},
#   'roof': {'latitude': 40.713984, 'longitude': -74.015963}},
#  'link': '/v3/places/60eda733a7ddae4973db6ee8',
#  'location': {'address': '250 Vesey St',
#   'census_block': '360610317031002',
#   'country': 'US',
#   'cross_street': 'Suite 107B',
#   'dma': 'New York',
#   'formatted_address': '250 Vesey St (Suite 107B), New York, NY 10281',
#   'locality': 'New York',
#   'postcode': '10281',
#   'region': 'NY'},
#  'name': 'Cicci Di Carne',
#  'related_places': {},
#  'timezone': 'America/New_York'}

# %%
data.keys()
# Out:
# dict_keys(['fsq_id', 'categories', 'chains', 'closed_bucket', 'geocodes', 'link', 'location', 'name', 'related_places', 'timezone'])

# %% [markdown]
# ####  Get the venue's overall rating

# %%
try:
    rating = data.get('rating')
    if rating is not None:
        print("Rating:", rating)
    else:
        print("This venue has not been rated yet.")
except KeyError:
    print("This venue has not been rated yet.")
# Out:
# This venue has not been rated yet.
